# %%
## Start date and End date?

# %%
# metrics on sessions, engagedSessions, file_download, right_click_file_download, eventCount, 
# and TotalUsers with the following 
# demensions: pagePath, eventName, fileName, data, city, region, country, serchTerm.

# %%
from google.analytics.data_v1beta import BetaAnalyticsDataClient
from google.analytics.data_v1beta.types import (
    DateRange,
    Dimension,
    Metric,
    RunReportRequest,
)
import pandas as pd
from datetime import datetime


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\skirar\Downloads\Quickstart-fc7c211302db.json"
client = BetaAnalyticsDataClient()
# Set up GA4 request
request = {
  "property": "properties/383872877",
  "date_ranges": [
    {
      "start_date": "2023-04-16",  # Adjust to your start date
      "end_date": "2024-05-16"   # Adjust to your end date
    }
  ],
  "dimensions": [
    {"name": "city"},
    {"name": "country"},
    {"name": "date"},
    {"name": "eventName"},
    {"name": "fileName"},
    {"name": "pagePath"},
    {"name": "region"},
    {"name": "searchTerm"}
  ],
  "metrics": [
    {"name": "eventCount"},
    {"name": "engagedSessions"},
    {"name": "sessions"},
    {"name": "totalUsers"},
    {"name": "keyEvents:file_download"},
    {"name": "keyEvents:right_click_file_download"}
  ]
}
# Execute GA4 request
response = client.run_report(request)
# Extract GA4 data into pandas DataFrame
data = []
for row in response.rows:
    dimension_values = [value.value for value in row.dimension_values]
    metric_values = [value.value for value in row.metric_values]
    data.append(dimension_values + metric_values)
columns = [dimension.name for dimension in response.dimension_headers] + [metric.name for metric in response.metric_headers]
df = pd.DataFrame(data, columns=columns)

# %%
df.head()
# Out:
#                         city        country      date      eventName fileName  \
# 0              Fort Atkinson  United States  20230615      page_view
# 1                    Hubbard  United States  20230614      page_view
# 2  Upper Providence Township  United States  20240325      page_view
# 3  Upper Providence Township  United States  20240325  session_start
# 4  Upper Providence Township  United States  20240325    first_visit
#
#                             pagePath        region searchTerm eventCount  \
# 0  /success-center/hoopla-bingepass/     Wisconsin                   279
# 1  /success-center/hoopla-bingepass/          Ohio                    87
# 2      /success-center/bonus-borrows  Pennsylvania                    70
# 3      /success-center/bonus-borrows  Pennsylvania                    60
# 4      /success-center/bonus-borrows  Pennsylvania                    58
#
#   engagedSessions sessions totalUsers keyEvents:file_download  \
# ...
